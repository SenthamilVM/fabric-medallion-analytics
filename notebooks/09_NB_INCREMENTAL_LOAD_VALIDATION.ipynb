-- %% [markdown]
-- ## Check number of rows in ***Silver*** before inserting data to test incremental load

-- %%
-- check row count BEFORE incrementally loading the data
SELECT COUNT(*) FROM sales_lakehouse.dbo.silver_crm_sales_details;

-- %% [markdown]
-- ## Check last_loaded_value in the incremental_load_control (watermark) table after Incremental Load

-- %%
SELECT last_loaded_value
    FROM incremental_load_control
    WHERE table_name = 'crm_sales_details';

-- %% [markdown]
-- ## Check number of rows in ***Silver*** AFTER inserting data to test incremental load

-- %%
-- check row count AFTER incrementally loading the data
SELECT COUNT(*) FROM sales_lakehouse.dbo.silver_crm_sales_details;
